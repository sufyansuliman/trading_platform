# %%
import pandas as pd 
spotMil = pd.read_csv("tracks_features.csv")
spot200 = pd.read_csv("Spot200.csv")
spotMil.head()
# Out:
#                        id                   name                      album  \
# 0  7lmeHLHBe4nmXzuXc0HDjk                Testify  The Battle Of Los Angeles
# 1  1wsRitfRRtWyEapl0q22o8        Guerrilla Radio  The Battle Of Los Angeles
# 2  1hR0fIFK2qRG3f3RF70pb7       Calm Like a Bomb  The Battle Of Los Angeles
# 3  2lbASgTSoDO7MTuLAXlTW0              Mic Check  The Battle Of Los Angeles
# 4  1MQTmpYOZ6fcMQc56Hdo7T  Sleep Now In the Fire  The Battle Of Los Angeles
#
#                  album_id                       artists  \
# 0  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 1  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 2  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 3  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 4  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
#
#                    artist_ids  track_number  disc_number  explicit  \
# 0  ['2d0hyoQ5ynDBnkvAbJKORj']             1            1     False
# ...

# %%
spot200["id"] = spot200["Link"].str.replace(pat='^(.*[\\\/])', repl='', regex=True)
spot200.head()
# Out:
#    Rank                                              Track            Artist  \
# 0     1                                            Starboy        The Weeknd
# 1     2                                             Closer  The Chainsmokers
# 2     3            Rockabye (feat. Sean Paul & Anne-Marie)      Clean Bandit
# 3     4                                    Let Me Love You          DJ Snake
# 4     5  I Don’t Wanna Live Forever (Fifty Shades Darke...              ZAYN
#
#     Streams                                               Link        Week  \
# 0  25734078  https://open.spotify.com/track/5aAx2yezTd8zXrk...  2017-01-06
# 1  23519705  https://open.spotify.com/track/7BKLCZ1jbUBVqRi...  2017-01-06
# 2  21216399  https://open.spotify.com/track/5knuzwU65gJK7IF...  2017-01-06
# 3  19852704  https://open.spotify.com/track/4pdPtRcBmOSQDlJ...  2017-01-06
# 4  18316326  https://open.spotify.com/track/3NdDpSvN911VPGi...  2017-01-06
#
# ...

# %%
spotMil["top200"] = spotMil["id"].isin(spot200["id"]).astype(int)
spotMil.head()
# Out:
#                        id                   name                      album  \
# 0  7lmeHLHBe4nmXzuXc0HDjk                Testify  The Battle Of Los Angeles
# 1  1wsRitfRRtWyEapl0q22o8        Guerrilla Radio  The Battle Of Los Angeles
# 2  1hR0fIFK2qRG3f3RF70pb7       Calm Like a Bomb  The Battle Of Los Angeles
# 3  2lbASgTSoDO7MTuLAXlTW0              Mic Check  The Battle Of Los Angeles
# 4  1MQTmpYOZ6fcMQc56Hdo7T  Sleep Now In the Fire  The Battle Of Los Angeles
#
#                  album_id                       artists  \
# 0  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 1  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 2  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 3  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 4  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
#
#                    artist_ids  track_number  disc_number  explicit  \
# 0  ['2d0hyoQ5ynDBnkvAbJKORj']             1            1     False
# ...

# %%
spotMil['year'] = spotMil['year'].astype(int)
spotMil = spotMil[spotMil['year'] >= 2017]
spotMil = spotMil[spotMil['year'] <= 2020]

# %%
spotMilOnes = spotMil[spotMil['top200'] == 1]
spotMilZeros = spotMil[spotMil['top200'] == 0]
spotMilOnes.head()
# Out:
#                            id  \
# 2592   4aarlAfLKVCTxUDNgbwhjH
# 2597   0A1hoCfMLkiAgvhWkkucJa
# 19325  70eFcWOvlMObDhURTqT4Fv
# 19326  4vUmTMuQqjdnvlZmAH61Qk
# 19327  4wuCQX7JvAZLlrcmH4AeZF
#
#                                                     name  \
# 2592                             Cry Baby (feat. DaBaby)
# 2597                                                Body
# 19325                    Beautiful People (feat. Khalid)
# 19326  South of the Border (feat. Camila Cabello & Ca...
# 19327      Cross Me (feat. Chance the Rapper & PnB Rock)
#
#                              album                album_id  \
# 2592                     Good News  0KjckH1EE6HRRurMIXSc0r
# 2597                     Good News  0KjckH1EE6HRRurMIXSc0r
# 19325  No.6 Collaborations Project  3oIFxDIo2fwuk4lwCmFZCx
# 19326  No.6 Collaborations Project  3oIFxDIo2fwuk4lwCmFZCx
# 19327  No.6 Collaborations Project  3oIFxDIo2fwuk4lwCmFZCx
#
#                                                artists  \
# ...

# %%
spotMilZeros.head()
# Out:
#                         id                name           album  \
# 22  2SwgVZn9S4NGueAaEAryf1    Man on a Mission  Do It for Love
# 23  0QCQ1Isa0YPVyIbs6JwpO1      Do It for Love  Do It for Love
# 24  3kIBEFhsZOeeKGebxRraOb  Someday We'll Know  Do It for Love
# 25  5dNDRw6qjDcnbW3luRhElU     Forever for You  Do It for Love
# 26  561UU4MvlsCenN1x7leYCh    Life's Too Short  Do It for Love
#
#                   album_id                      artists  \
# 22  4evw6IBex3N8x1oA2axMTH  ['Daryl Hall & John Oates']
# 23  4evw6IBex3N8x1oA2axMTH  ['Daryl Hall & John Oates']
# 24  4evw6IBex3N8x1oA2axMTH  ['Daryl Hall & John Oates']
# 25  4evw6IBex3N8x1oA2axMTH  ['Daryl Hall & John Oates']
# 26  4evw6IBex3N8x1oA2axMTH  ['Daryl Hall & John Oates']
#
#                     artist_ids  track_number  disc_number  explicit  \
# 22  ['77tT1kLj6mCWtFNqiOmP9H']             1            1     False
# 23  ['77tT1kLj6mCWtFNqiOmP9H']             2            1     False
# ...

# %%
sampledZeros = spotMilZeros.sample(n = 2000)
sampledZeros.head()
# Out:
#                              id  \
# 762701   7HzvreCLbveQe50p8YSEGP
# 824280   1SvKos8CEkP8B9UqNuGgr5
# 1123794  5mdEJeUnUcGcOwUcjd9YdT
# 1008345  6hLJMY3GSk8rvFs2so4Qoc
# 856903   3mYqpet8PJ9ce7bVHot75l
#
#                                                       name  \
# 762701   25 Variations & Fugue on a Theme by Handel, Op...
# 824280                                          Acrobotics
# 1123794                                     Borrowed Light
# 1008345                                         Pacha Mama
# 856903                                         Blues Etude
#
#                                                      album  \
# 762701   Brahms: Handel Variations, 7 Fantasies & Chora...
# 824280                                                 Hex
# 1123794                   Set My Heart On Fire Immediately
# 1008345                                         Holy Child
# 856903                            The Stylings of Champian
#
# ...

# %%
combinedDF = pd.concat([sampledZeros, spotMilOnes], axis = 0)
combinedDF.head()
# Out:
#                              id  \
# 762701   7HzvreCLbveQe50p8YSEGP
# 824280   1SvKos8CEkP8B9UqNuGgr5
# 1123794  5mdEJeUnUcGcOwUcjd9YdT
# 1008345  6hLJMY3GSk8rvFs2so4Qoc
# 856903   3mYqpet8PJ9ce7bVHot75l
#
#                                                       name  \
# 762701   25 Variations & Fugue on a Theme by Handel, Op...
# 824280                                          Acrobotics
# 1123794                                     Borrowed Light
# 1008345                                         Pacha Mama
# 856903                                         Blues Etude
#
#                                                      album  \
# 762701   Brahms: Handel Variations, 7 Fantasies & Chora...
# 824280                                                 Hex
# 1123794                   Set My Heart On Fire Immediately
# 1008345                                         Holy Child
# 856903                            The Stylings of Champian
#
# ...

# %%
combinedDF.to_csv('SpotifySamples.csv')
